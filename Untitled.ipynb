# %%
import pandas as pd

# %%
df = pd.read_csv('country.csv')

# %%
df['Found'] = df['Name'].str.find('ru')

# %%
df.loc[df.loc[:,'Found'] != -1 ]
# Out:
#      Unnamed: 0 Code     Name      Continent          Region  SurfaceArea  \
# 0             0  ABW    Aruba  North America       Caribbean        193.0
# 17           17  BDI  Burundi         Africa  Eastern Africa      27834.0
# 26           26  BLR  Belarus         Europe  Eastern Europe     207600.0
# 32           32  BRN   Brunei           Asia  Southeast Asia       5765.0
# 54           54  CYP   Cyprus           Asia     Middle East       9251.0
# 161         161  NRU    Nauru        Oceania      Micronesia         21.0
# 167         167  PER     Peru  South America   South America    1285216.0
# 222         222  URY  Uruguay  South America   South America     175016.0
#
#      IndepYear  Population  LifeExpectancy      GNP          LocalName  \
# 0          NaN      103000            78.4    828.0              Aruba
# 17      1962.0     6695000            46.2    903.0   Burundi/Uburundi
# 26      1991.0    10236000            68.0  13714.0            Belarus
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Code', 'Name', 'Continent', 'Region', 'SurfaceArea',
#        'IndepYear', 'Population', 'LifeExpectancy', 'GNP', 'LocalName',
#        'GovernmentForm', 'HeadOfState', 'Capital', 'Found'],
#       dtype='object')
